# %% [markdown]
# ## Connect met Neo4j

# %%
# Kopier vanaf sandbox.neo4j.com

from neo4j import GraphDatabase, basic_auth

driver = GraphDatabase.driver(
  "neo4j://3.95.151.25:7687",
  auth=basic_auth("neo4j", "XX"))

cypher_query = '''
MATCH (a:Airport{iata:$iata})-[r:HAS_ROUTE]->(other)
  RETURN other.iata as destination
'''

with driver.session(database="neo4j") as session:
  results = session.read_transaction(
    lambda tx: tx.run(cypher_query,
                      iata="DEN").data())
  for record in results:
    print(record['destination'])

driver.close()
# Out:
# C:\Users\9040449\AppData\Local\Temp\ipykernel_29188\3140675030.py:16: DeprecationWarning: read_transaction has been renamed to execute_read
#   results = session.read_transaction(
# Failed to read from defunct connection ResolvedIPv4Address(('3.95.151.25', 7687)) (IPv4Address(('3.95.151.25', 7687)))
# Transaction failed and will be retried in 0.8597210083763356s (Failed to read from defunct connection ResolvedIPv4Address(('3.95.151.25', 7687)) (IPv4Address(('3.95.151.25', 7687))))
# Failed to read from defunct connection ResolvedIPv4Address(('3.95.151.25', 7687)) (IPv4Address(('3.95.151.25', 7687)))
# Transaction failed and will be retried in 1.743863730928287s (Failed to read from defunct connection ResolvedIPv4Address(('3.95.151.25', 7687)) (IPv4Address(('3.95.151.25', 7687))))
# TUL
# XNA
# CAK
# ATW
# KOA
# CLE
# KEF
# ALS
# ATL
# DDC
# BUF
# CHS
# CYS
# BFM
# DAY
# PGA
# ONT
# FSD
# RAP
# MCI
# BFL
# PNS
# SHV
# CEZ
# PVR
# GCM
# ISN
# AUS
# MAF
# BKG
# TYS
# OGG
# MKE
# DFW
# ...

# %% [markdown]
# ## Werk met Neo4j

# %%
from graphdatascience import GraphDataScience
gds = GraphDataScience(driver, aura_ds=True)
